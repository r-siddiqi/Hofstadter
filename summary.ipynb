# %%
from lattice_types.honeycomb import Honeycomb_Hamiltonian
from lattice_types.square import Square_Hamiltonian
from lattice_types.triangular import Triangular_Hamiltonian
from lattice_types.plotting import Plotting_Functions

# %% [markdown]
# This notebook serves as an example for how to import the lattice types and plotting functions in order to generate different plots for specific cases. The plots automatically save into the "plots" folder organized by parameters.
#
# The butterfly construction is built into the classes constructing Hamiltonians for each lattice type as it depends on the specific construction.

# %% [markdown]
# Honeycomb Tests

# %%
# Define Simulation Parameters

length_h = 10   # Lattice dimension
t_h = 1         # Hopping parameter
W_h = 0.0       # Disorder strength
phi_h = 0.5     # Magnetic flux per plaquette
q_h = 50        # Maximum denominator for phi values


# Initialize the Honeycomb

Honeycomb = Honeycomb_Hamiltonian(length_h, t_h, W_h, phi_h, q_h, save = True)

# Generate outputs of the honeycomb pass through to plot
honeycomb_outputs = Honeycomb.prepare_outputs()

# Initializing Honeycomb plotting
honeycomb_plot = Plotting_Functions(honeycomb_outputs, save = True)

# Plot the eigenvalue spectrum
honeycomb_plot.plot_evals(save = True)

# Plot a random eigenvector
honeycomb_plot.plot_evec(save = True)

# Plot the inverse participation ratio
honeycomb_plot.plot_pr(save = True)

# Plot the density of states
honeycomb_plot.plot_density_of_states(save = True)

# Plot the butterfly
Honeycomb.plot_hofstadter_butterfly(save = True)

# %% [markdown]
# Square Tests

# %%
# Initialize the Square
Square = Square_Hamiltonian(length=10, t=1, W=0.0, phi=0.0, q=50, save = True)

# Generate outputs of the square pass through to plot
square_outputs = Square.prepare_outputs()

# Initializing Honeycomb plotting
square_plot = Plotting_Functions(square_outputs, save = True)

# Plot the Eigenvalue spectrum of the Square
square_plot.plot_evals(save = True)

Square.plot_hofstadter_butterfly(save = True)

# %%
# Initialize the Square
Square = Square_Hamiltonian(length=10, t=1, W=0.5, phi=0.0, q=50, save = True)

# Generate outputs of the square pass through to plot
square_outputs = Square.prepare_outputs()

# Initializing Honeycomb plotting
square_plot = Plotting_Functions(square_outputs, save = True)

# Plot the Eigenvalue spectrum of the Square
square_plot.plot_evals(save = True)

Square.plot_hofstadter_butterfly(save = True)

# %% [markdown]
# Triangular Test

# %%
# Initialize the Square
Tri = Triangular_Hamiltonian(length=10, t=1, W=0.0, phi=0.0, q=50, save = True)

# Generate outputs of the square pass through to plot
tri_outputs = Tri.prepare_outputs()

# Initializing Honeycomb plotting
tri_plot = Plotting_Functions(tri_outputs, save = True)

# Plot the Eigenvalue spectrum of the Square
tri_plot.plot_evals(save = True)

Tri.plot_hofstadter_butterfly(save = True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 5
#       2 Tri = Triangular_Hamiltonian(length=10, t=1, W=0.0, phi=0.0, q=50, save = True)
#       4 # Generate outputs of the square pass through to plot
# ----> 5 tri_outputs = Tri.prepare_outputs()
#       7 # Initializing Honeycomb plotting
#       8 tri_plot = Plotting_Functions(tri_outputs, save = True)
#
# File c:\Users\17135\lattice_project\PHY-329_Project\lattice_types\triangular.py:154, in prepare_outputs(self)
#     150 def prepare_outputs(self):
#     151     """
#     152     Package all relevant parameters and diagonalization
#     153     outputs in a tuple to pass onto independent plotting functions.
# --> 154
#     155     Returns:
#     156         tuple: Parameter inputs for plotting functions.
#     157     """
#     158     self.evals, self.evecs = self.construct_hamiltonian()
# ...

# %%
# Initialize the Square
Tri = Triangular_Hamiltonian(length=10, t=1, W=0.7, phi=0.4, q=50, save = True)

# Generate outputs of the square pass through to plot
tri_outputs = Tri.prepare_outputs()

# Initializing Honeycomb plotting
tri_plot = Plotting_Functions(tri_outputs, save = True)

# Plot the Eigenvalue spectrum of the Square
tri_plot.plot_evals(save = True)

Tri.plot_hofstadter_butterfly(save = True)
